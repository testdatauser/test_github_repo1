# %%
# !pip install scikit-learn==0.22
# Out:
# Collecting scikit-learn==0.22
#   Using cached https://files.pythonhosted.org/packages/19/96/8034e350d4550748277e514d0d6d91bdd36be19e6c5f40b8af0d74cb0c84/scikit_learn-0.22-cp37-cp37m-manylinux1_x86_64.whl
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.22) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.22) (1.5.4)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn==0.22) (1.0.1)
# ERROR: pyldavis 3.3.1 has requirement numpy>=1.20.0, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: pyldavis 3.3.1 has requirement pandas>=1.2.0, but you'll have pandas 1.1.5 which is incompatible.
# ERROR: pycaret 2.3.4 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.22 which is incompatible.
# ERROR: lightgbm 3.2.1 has requirement scikit-learn!=0.22.0, but you'll have scikit-learn 0.22 which is incompatible.
# ERROR: kyd 0.1.8 has requirement numpy==1.19.2, but you'll have numpy 1.19.5 which is incompatible.
# ERROR: kyd 0.1.8 has requirement scikit-learn==0.20.3, but you'll have scikit-learn 0.22 which is incompatible.
# ERROR: imbalanced-learn 0.7.0 has requirement scikit-learn>=0.23, but you'll have scikit-learn 0.22 which is incompatible.
# Installing collected packages: scikit-learn
#   Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# Successfully installed scikit-learn-0.22
# WARNING: You are using pip version 19.3.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import configparser
import ast
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from pycaret.datasets import get_data 
from pycaret.classification import *
import copy
import os
import requests
from auto_learning_utility import *
import mlflow
from mosaicml import *
from mosaicml.constants import MLModelFlavours
# from plots import roc_confusion_matrix_plot, feature_imp_plot
# from db_connection import connection_string,db_engine
from pycaret.internal.tabular import _calculate_metrics_supervised

# %%
# !pip install xlrd==1.1.0
# Out:
# Collecting xlrd==1.1.0
#   Downloading https://files.pythonhosted.org/packages/07/e6/e95c4eec6221bfd8528bcc4ea252a850bffcc4be88ebc367e23a1a84b0bb/xlrd-1.1.0-py2.py3-none-any.whl (108kB)
#      |████████████████████████████████| 112kB 30.1MB/s eta 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-1.1.0
# WARNING: You are using pip version 19.3.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
config = configparser.ConfigParser()
config.read('/notebooks/notebooks/code/config_autolearning.ini')
# Out:
# ['/notebooks/notebooks/code/config_autolearning.ini']

# %%
# base_path = config.get('BASE_PATH','base_path')

# %%
feedback_data = config.get('FEEDBACK_DATA','feedback_data')
# df = pd.read_excel(os.path.join(base_path, feedback_data))

# %%
df = pd.read_excel(feedback_data)

# %%
train_y_column = ast.literal_eval(config.get("COLUMNS", "train_y_column"))
config.set('COLUMNS', 'train_x_column_list', str(df.drop(train_y_column,axis=1).columns.to_list())) ##whatever list we can enter here
with open('config.ini', 'w') as configfile:
    config.write(configfile)
train_x_column_list = ast.literal_eval(config.get("COLUMNS", "train_x_column_list"))
ai = config.get('LEARNING_TYPE','ai')
save_model_path = config.get('SAVE_MODEL_PATH','save_model_path')

# %%
if ai == 'base_ai':
    df = pd.DataFrame(columns = df.columns.to_list(),index=[0])
    df.iloc[0] = 0
    df.ci_distance.iloc[0] = 99
    df = df.astype('int')
else:
    df = pd.read_excel(feedback_data)
#     df = pd.read_excel(os.path.join(base_path, feedback_data))

# %%
train_columns = ['ci_distance',
       'time_diff', 'time_diff_s', 'application_service', 'u_business_service',
       'service_comp', 'domain_comp', 'data_center_comp', 'ci_similarity',
       'cr_comp', 'ci_pred', 'alert_pred', 'weighted_proba', 'kb']

# %%
total_columns = copy.deepcopy(train_columns)
total_columns.append(train_y_column)

# %% [markdown]
# # 1. Setup dataset

# %%
#categorical_features_name = ['ci_distance','application_service','u_business_service','cr_comp']

# %%
df= df[df.time_diff <= 15].reset_index().drop(columns='index')

# %%
## this need to be added in config
num_col = ['ci_distance', 'time_diff', 'time_diff_s','ci_similarity','ci_pred', 'alert_pred', 'weighted_proba']
cat_col = ['application_service','u_business_service', 'service_comp', 'domain_comp', 'data_center_comp', 'cr_comp','kb']

# %%
exp_name='ns3_hybrid_model'

# %%
clf1 = setup(data = df[total_columns],numeric_features = num_col,categorical_features=cat_col, target = train_y_column, log_experiment=False, experiment_name=exp_name,silent=True,preprocess=False)
# Out:
# <style  type="text/css" >
# </style><table id="T_93e25c22_2025_11ec_beb2_a61437d249ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow0_col1" class="data row0 col1" >6020</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow1_col1" class="data row1 col1" >Actual (Validated)</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow3_col1" class="data row3 col1" >correlated: 0, non-correlated: 1</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow4_col1" class="data row4 col1" >(210, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow6_col1" class="data row6 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow7_col1" class="data row7 col1" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow8_col0" class="data row8 col0" >Transformed Train Set</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow8_col1" class="data row8 col1" >(146, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow9_col0" class="data row9 col0" >Transformed Test Set</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow9_col1" class="data row9 col1" >(64, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow10_col0" class="data row10 col0" >Shuffle Train-Test</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow10_col1" class="data row10 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow11_col0" class="data row11 col0" >Stratify Train-Test</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow11_col1" class="data row11 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow12_col0" class="data row12 col0" >Fold Generator</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow12_col1" class="data row12 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow13_col0" class="data row13 col0" >Fold Number</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow13_col1" class="data row13 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow14_col0" class="data row14 col0" >CPU Jobs</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow14_col1" class="data row14 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow15_col0" class="data row15 col0" >Use GPU</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow15_col1" class="data row15 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow16_col0" class="data row16 col0" >Log Experiment</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow17_col0" class="data row17 col0" >Experiment Name</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow17_col1" class="data row17 col1" >ns3_hybrid_model</td>
#             </tr>
#             <tr>
#                         <th id="T_93e25c22_2025_11ec_beb2_a61437d249eclevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow18_col0" class="data row18 col0" >USI</td>
#                         <td id="T_93e25c22_2025_11ec_beb2_a61437d249ecrow18_col1" class="data row18 col1" >0aa0</td>
#             </tr>
#             <tr>

# %% [markdown]
# # 2. Create Model

# %%
# #rf = create_model('rf',X_train_data=train_X,y_train_data=train_y)
#rf = create_model('rf')

# %%
#best = compare_models(include=['ada', 'et', 'gbc', 'rf','lr'],sort='AUC')
best = compare_models(include=['et','rf','lr'],sort='Prec.')
best_model_name = pull()
# Out:
# <style  type="text/css" >
#     #T_99e4da5a_2025_11ec_beb2_a61437d249ec th {
#           text-align: left;
#     }#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col0,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col0,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col2,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col0,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col1,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col2,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col3,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col4,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col5,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col6,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col1,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col2,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col3,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col4,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col5,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col6,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col7,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col1,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col3,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col4,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col5,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col6,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col8,#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_99e4da5a_2025_11ec_beb2_a61437d249ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_99e4da5a_2025_11ec_beb2_a61437d249eclevel0_row0" class="row_heading level0 row0" >et</th>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col1" class="data row0 col1" >0.9657</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col2" class="data row0 col2" >0.9972</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col3" class="data row0 col3" >0.9735</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col4" class="data row0 col4" >0.9846</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col5" class="data row0 col5" >0.9781</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col6" class="data row0 col6" >0.8960</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col7" class="data row0 col7" >0.9050</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow0_col8" class="data row0 col8" >0.4870</td>
#             </tr>
#             <tr>
#                         <th id="T_99e4da5a_2025_11ec_beb2_a61437d249eclevel0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col1" class="data row1 col1" >0.9657</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col2" class="data row1 col2" >0.9806</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col3" class="data row1 col3" >0.9735</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col4" class="data row1 col4" >0.9846</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col5" class="data row1 col5" >0.9781</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col6" class="data row1 col6" >0.8960</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col7" class="data row1 col7" >0.9050</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow1_col8" class="data row1 col8" >0.3570</td>
#             </tr>
#             <tr>
#                         <th id="T_99e4da5a_2025_11ec_beb2_a61437d249eclevel0_row2" class="row_heading level0 row2" >lr</th>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col0" class="data row2 col0" >Logistic Regression</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col1" class="data row2 col1" >0.9110</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col2" class="data row2 col2" >0.9697</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col3" class="data row2 col3" >0.9636</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col4" class="data row2 col4" >0.9335</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col5" class="data row2 col5" >0.9453</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col6" class="data row2 col6" >0.6775</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col7" class="data row2 col7" >0.6990</td>
#                         <td id="T_99e4da5a_2025_11ec_beb2_a61437d249ecrow2_col8" class="data row2 col8" >0.0160</td>
#             </tr>
#     </tbody></table>

# %%
best_model_name = {k: v for k, v in best_model_name.iloc[0,0:1].items()}

# %%
# tune hyperparameters with custom_grid
params = {"max_depth": np.random.randint(1, (len(df[train_columns].columns)*.85),20),
         "max_features": ["auto"],
          "min_samples_leaf": [1,2,3,4,5,6], #remove 1 after more data
          "max_leaf_nodes" : [None],
          "max_samples" : [None],
          "min_impurity_decrease": [0.0], 
          "min_impurity_split": [None],
          "min_samples_split":[2,4,6],
          "n_estimators":[100],      
          "criterion": ["gini", "entropy"]}

# %%
plot_model(best, plot = 'confusion_matrix')

# %% [markdown]
# # 3. Tune Hyperparameters

# %%
tuned_best_model = tune_model(best,optimize='Prec.')
#tuned_best_model = tune_model(best_model,optimize='Prec.',custom_grid=params)
# Out:
# <style  type="text/css" >
# #T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col0,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col1,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col2,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col3,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col4,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col5,#T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow10_col6{
#             background:  yellow;
#         }</style><table id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col0" class="data row0 col0" >0.9333</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col2" class="data row0 col2" >0.9167</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col3" class="data row0 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col4" class="data row0 col4" >0.9565</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col5" class="data row0 col5" >0.8148</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow0_col6" class="data row0 col6" >0.8292</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col0" class="data row1 col0" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col3" class="data row1 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col4" class="data row1 col4" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col5" class="data row1 col5" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow1_col6" class="data row1 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col0" class="data row2 col0" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col1" class="data row2 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col2" class="data row2 col2" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col3" class="data row2 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col4" class="data row2 col4" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col5" class="data row2 col5" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow2_col6" class="data row2 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col0" class="data row3 col0" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col1" class="data row3 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col2" class="data row3 col2" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col4" class="data row3 col4" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col5" class="data row3 col5" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow3_col6" class="data row3 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col0" class="data row4 col0" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col2" class="data row4 col2" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col4" class="data row4 col4" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col5" class="data row4 col5" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow4_col6" class="data row4 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col0" class="data row5 col0" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col1" class="data row5 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col2" class="data row5 col2" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col4" class="data row5 col4" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col5" class="data row5 col5" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow5_col6" class="data row5 col6" >1.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col0" class="data row6 col0" >0.9286</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col1" class="data row6 col1" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col2" class="data row6 col2" >0.9091</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col3" class="data row6 col3" >1.0000</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col4" class="data row6 col4" >0.9524</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col5" class="data row6 col5" >0.8108</td>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow6_col6" class="data row6 col6" >0.8257</td>
#             </tr>
#             <tr>
#                         <th id="T_b1f4bf7a_2025_11ec_beb2_a61437d249eclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_b1f4bf7a_2025_11ec_beb2_a61437d249ecrow7_co

# %%
# plotting a model
plot_model(tuned_best_model)

# %%
plot_model(tuned_best_model, plot = 'confusion_matrix')

# %%
plot_model(tuned_best_model, plot = 'boundary')

# %%
plot_model(tuned_best_model, plot = 'feature')

# %%
plot_model(tuned_best_model, plot = 'pr')

# %%
plot_model(tuned_best_model, plot = 'class_report',)

# %% [markdown]
# # 4. Interpret Model

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading https://files.pythonhosted.org/packages/b9/f4/c5b95cddae15be80f8e58b25edceca105aa83c0b8c86a1edad24a6af80d3/shap-0.39.0.tar.gz (356kB)
#      |████████████████████████████████| 358kB 20.0MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from shap) (1.19.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.7/site-packages (from shap) (1.5.4)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from shap) (0.22)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from shap) (1.1.5)
# Requirement already satisfied: tqdm>4.25.0 in /opt/conda/lib/python3.7/site-packages (from shap) (4.62.0)
# Collecting slicer==0.0.7
#   Downloading https://files.pythonhosted.org/packages/78/c2/b3f55dfdb8af9812fdb9baf70cacf3b9e82e505b2bd4324d588888b81202/slicer-0.0.7-py3-none-any.whl
# Requirement already satisfied: numba in /opt/conda/lib/python3.7/site-packages (from shap) (0.53.1)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from shap) (1.2.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->shap) (1.0.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas->shap) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from numba->shap) (49.6.0.post20210108)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /opt/conda/lib/python3.7/site-packages (from numba->shap) (0.36.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->shap) (1.16.0)
# Building wheels for collected packages: shap
#   Building wheel for shap (setup.py) ... done
#   Created wheel for shap: filename=shap-0.39.0-cp37-cp37m-linux_x86_64.whl size=544629 sha256=47c337bf6efa2e30077f6ed00978b497ad3d24388dd3828d8e2916a85347987d
#   Stored in directory: /home/mosaic-ai/.cache/pip/wheels/15/27/f5/a8ab9da52fd159aae6477b5ede6eaaec69fd130fa0fa59f283
# Successfully built shap
# Installing collected packages: slicer, shap
# Successfully installed shap-0.39.0 slicer-0.0.7
# WARNING: You are using pip version 19.3.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
if best_model_name['Model'] in ['Logistic Regression','Ada Boost Classifier','Gradient Boosting Classifier']:
    print('This function only supports tree based models for binary classification: xgboost, catboost, dt, lightgbm, et, rf.')
else:
    interpret_model(tuned_best_model)

# %%
if best_model_name['Model'] in ['Logistic Regression','Ada Boost Classifier','Gradient Boosting Classifier']:
    print('This function only supports tree based models for binary classification: xgboost, catboost, dt, lightgbm, et, rf.')
else:
    interpret_model(best, plot = 'correlation')

# %%
if best_model_name['Model'] in ['Logistic Regression','Ada Boost Classifier','Gradient Boosting Classifier']:
    print('This function only supports tree based models for binary classification: xgboost, catboost, dt, lightgbm, et, rf.')
else:
    interpret_model(best, plot = 'reason', observation = 21)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# # 5. Test Model

# %%
tuned_best_model
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='gini',
#                      max_depth=4, max_features='log2', max_leaf_nodes=None,
#                      max_samples=None, min_impurity_decrease=0.0002,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=10, min_weight_fraction_leaf=0.0,
#                      n_estimators=240, n_jobs=-1, oob_score=False,
#                      random_state=6020, verbose=0, warm_start=False)

# %%
predictions = predict_model(tuned_best_model)
predictions.head()
# Out:
# <style  type="text/css" >
# </style><table id="T_c1e8815a_2025_11ec_beb2_a61437d249ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c1e8815a_2025_11ec_beb2_a61437d249eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col1" class="data row0 col1" >0.9531</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col2" class="data row0 col2" >0.9944</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col3" class="data row0 col3" >0.9444</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col4" class="data row0 col4" >1.0000</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col5" class="data row0 col5" >0.9714</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col6" class="data row0 col6" >0.8416</td>
#                         <td id="T_c1e8815a_2025_11ec_beb2_a61437d249ecrow0_col7" class="data row0 col7" >0.8523</td>
#             </tr>
#     </tbody></table>
#    ci_distance  time_diff  time_diff_s application_service u_business_service  \
# 0         99.0        0.0          0.0                   0                  0
# 1         99.0        0.0          0.0                   0                  0
# 2         99.0        0.0          0.0                   0                  0
# 3         99.0        0.0          0.0                   0                  0
# 4         99.0        0.0          0.0                   0                  0
#
#   service_comp domain_comp data_center_comp  ci_similarity cr_comp   ci_pred  \
# 0            0           0                0          0.296       0  1.000000
# 1            0           0                0          0.160       0  0.000000
# 2            0           0                0          0.192       0  0.000000
# 3            0           0                0          0.188       0  0.785714
# 4            0           0                0          0.168       0  0.000000
#
#    alert_pred  weighted_proba kb Actual (Validated)           Label   Score
# 0         1.0        1.000000  0         correlated      correlated  0.9118
# 1         1.0        0.250000  0     non-correlated  non-correlated  0.8240
# 2         1.0        0.250000  0     non-correlated  non-correlated  0.7993
# 3         1.0        0.839286  0         correlated      correlated  0.8617
# 4         1.0        0.250000  0     non-correlated  non-correlated  0.8197

# %%
## Save this in database with timestamp and show on UI
results = pull()

# %% [markdown]
# # 6. Finalize model

# %%
finalize_model(tuned_best_model)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0,
#                      class_weight='balanced_subsample', criterion='gini',
#                      max_depth=4, max_features='log2', max_leaf_nodes=None,
#                      max_samples=None, min_impurity_decrease=0.0002,
#                      min_impurity_split=None, min_samples_leaf=2,
#                      min_samples_split=10, min_weight_fraction_leaf=0.0,
#                      n_estimators=240, n_jobs=-1, oob_score=False,
#                      random_state=6020, verbose=0, warm_start=False)

# %%
final_model = finalize_model(tuned_best_model)

# %%
## because of this model explainability will not work
#plot_model(final_model, plot='calibration')
#calibrated_model = calibrate_model(final_model, method = 'isotonic')
#plot_model(calibrated_model, plot='calibration')

# %%
hybrid_model = RuleAugmentedEstimator(final_model,[ai])

# %%
#train_columns = ['ci_distance', 'kb', 'application_service', 'time_diff', 'u_business_service', 'time_diff_s', 'cr_comp', 'ci_similarity', 'weighted_proba']
# train_X = df[train_columns]
# train_y = df[train_y_column].values

# %%
hybrid_model.fit(df[train_columns], df[train_y_column].values)

# %%
predictions = hybrid_model.predict(df[train_columns])
#predictions_proba = final_model.predict_proba(df,trained_columns=train_columns)
# x = train_X.copy()
# x['predicted'] = predictions
# x['actual'] = df['final_class_of_prediction']

# %% [markdown]
# # 7. Register Model

# %%
@scoring_func
def score(model, payload):
#     payload = request.json["payload"]
    payload = payload["payload"]
    data = pd.DataFrame(eval(payload))
    result= model.predict(data)
#     result = 1- result[:,0]
#     result = np.float64(result)
    result = result.tolist()
    return result

# %%
# tenant_id = os.getenv('tenant_id')
tenant_id = 'python_3_7_new_2'
model_name = 'Hybrid_Model' + "_" + str(tenant_id)

# %%
register_model_output = register_model(hybrid_model, score, name=model_name, 
                description="Predict correlation",
                flavour=MLModelFlavours.sklearn, pretty_output=False)

# %%
register_model_output['versions'] = sorted(register_model_output['versions'], key=lambda x : x['created_on'], reverse=True)
register_model_output_version = register_model_output['versions'][0]['id']

# %%
register_model_output_id = register_model_output['id']

# %%
hardware_id = 'df2109b5-66fb-4b89-b249-5d1731e3e91e'

# %%
## deploy model 
model_deploy = deploy_model(register_model_output_id, register_model_output_version, hardware_id)

# %%
requests.json = {"payload": df[train_columns].loc[1:3].to_json()}

# %%
print(requests.json)
# Out:
# {'payload': '{"ci_distance":{"1":99,"2":99,"3":99},"time_diff":{"1":0,"2":0,"3":0},"time_diff_s":{"1":0,"2":0,"3":0},"application_service":{"1":0,"2":0,"3":0},"u_business_service":{"1":0,"2":0,"3":0},"service_comp":{"1":0,"2":0,"3":0},"domain_comp":{"1":0,"2":0,"3":0},"data_center_comp":{"1":0,"2":0,"3":0},"ci_similarity":{"1":0.228,"2":0.2,"3":0.168},"cr_comp":{"1":0,"2":0,"3":0},"ci_pred":{"1":0.0,"2":0.0,"3":0.0},"alert_pred":{"1":1.0,"2":1.0,"3":1.0},"weighted_proba":{"1":0.25,"2":0.25,"3":0.25},"kb":{"1":0,"2":0,"3":0}}'}

# %%
js = requests.json

# %%
score(hybrid_model,js)
# Out:
# ['non-correlated', 'non-correlated', 'non-correlated']

# %% [markdown]
# ## 8. Save Artifacts and Metrics

# %% [markdown]
# #### 8.1 Save plot artifacts

# %%
# ### save plots
# confusion_mat_path= roc_confusion_matrix_plot(estimator=final_model,x_test=get_config('X_test'),y_test=get_config('y_test'),plot_type='confusion_matrix',plot_name='confusion_matrix.jpg')
# roc_path= roc_confusion_matrix_plot(estimator=final_model,x_test=get_config('X_test'),y_test=get_config('y_test'),plot_type='roc_curve',plot_name='roc_curve.jpg')
# #feature_imp_path= feature_imp_plot(estimator=final_model,data=get_config('X_train'),plot_name='feature_importance.jpg')

# %% [markdown]
# #### 8.2 save params and metrics

# %%
# score_results = {k: v for k, v in results.iloc[0,1:].items()}
# final_params = final_model.get_params()

# %% [markdown]
# #### 8.3 build DB connection string & set tracking

# %%
# db_uri = connection_string(config_path='config.ini')

# %%
# mlflow.set_tracking_uri(db_uri)

# %% [markdown]
# #### 8.4 add saving artifact location

# %%
# artifact_path= os.path.join(base_path, config.get('MLFLOW','artifacts_location'))
# artifact_string = config.get('MLFLOW','artifact_path_string')
# artifacts_location = artifact_string.format(**dict(base_path=artifact_path))

# %% [markdown]
# ### 8.5 Run mlflow to store all artifacts with versioning and metrics to DB

# %%
# try:
#     mlflow.create_experiment(name=exp_name,artifact_location=artifacts_location)
# except:
#     mlflow.set_experiment(exp_name)

#     with mlflow.start_run():
#         mlflow.sklearn.log_model(sk_model=final_model,
#                                  artifact_path='')
#         mlflow.log_params(final_params)
#         mlflow.log_metrics(score_results)
#         mlflow.log_artifact(confusion_mat_path, artifact_path='plots')
#         mlflow.log_artifact(roc_path, artifact_path='plots')
#         run_id = mlflow.active_run().info.run_id
#         #mlflow.log_artifact(feature_imp_path, artifact_path='plots')
#         mlflow.end_run()

# %% [markdown]
# ## 9. Model Deployment

# %% [markdown]
# #### 9. Register a model if not register or get list of registered model

# %%
# stage='Staging'
# client = mlflow.tracking.MlflowClient()
# if not client.list_registered_models():
#     model_uri = os.path.join(artifact_path,run_id,'artifacts')
#     try:
#         client.create_registered_model(name=model_name,description=best_model_name['Model'])
#         model_details = client.create_model_version(name=model_name,run_id=run_id,source=model_uri,description=best_model_name['Model'])
#         client.transition_model_version_stage(name=model_name,stage=stage,version=model_details.version) 
#     except:
#         model_details = client.create_model_version(name=model_name,run_id=run_id,source=model_uri,description=best_model_name['Model'])
#         client.transition_model_version_stage(name=model_name,stage=stage,version=model_details.version) 
#     print("No registered model found, registering model by name: {n}, version no: {v}, stage: {s}".format(n=model_name, v=model_details.version, s=stage))
# else:
#     registered_model_list= client.list_registered_models()
#     print("Total {r} registered models found".format(r=len(registered_model_list)))
# Out:
# Total 1 registered models found

# %% [markdown]
# #### 9.2 Get registered model details

# %%
# ### create a dict of registered model with run id, model path to read model and model description
# reg_details = dict()
# for i in registered_model_list:
#     for v in i.latest_versions:
#         reg_details['run_id'] = v.run_id
#         reg_details['model_path'] = v.source
#         reg_details['model_description'] = v.description

# %% [markdown]
# #### 9.3 Get registered model metrics

# %%
# query = "select key,value from mlflow_db_aiops.public.metrics where run_uuid='{}'".format(reg_details['run_id'])
# engine = db_engine(config_path='config.ini')
# metrics_df = pd.read_sql_query(sql=query,con=engine)
# reg_details.update(dict(zip(metrics_df.key,metrics_df.value))) ## update metrics to reg_details dict

# %% [markdown]
# #### 9.4 Load registered model and test on new test data

# %%
# reg_model_ = pd.read_pickle(os.path.join(reg_details['model_path'],'model.pkl'))

# %%
# yhat = reg_model_.predict_proba(get_config('X_test'))
# y = reg_model_.predict(get_config('X_test'))
# pos_probs = yhat[:, 1]
# # calculate metrics
# reg_new_df_metrics= _calculate_metrics_supervised(y_test=get_config('y_test'),pred=y,pred_prob=pos_probs)

# %%
# auc_diff = (score_results['AUC']-reg_new_df_metrics['AUC'])/score_results['AUC']

# %%
# if auc_diff.round(4) <= -0.05:
#     print("Keep old model, Required human retraining")
# else:
#     model_uri = os.path.join(artifact_path,run_id,'artifacts')
#     model_details = client.create_model_version(name=model_name,run_id=run_id,source=model_uri,description=best_model_name['Model'])
#     client.transition_model_version_stage(name=model_name,stage=stage,version=model_details.version)
# Out:
# 2021/06/24 15:23:29 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: Hybrid_Model, version 4
